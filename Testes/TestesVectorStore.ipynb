# %% [markdown]
# # Create VectorStore

# %%
import requests
key="eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiJINWNwUGpicUpFdFdKMjdTSlI5UFNNZUY1N09xQ1lRVWhjejJCa3UyTFNQa01qVVB5VUVTVWhNZFNOZnVhQnZRRmMtZFhYc0ZvUWFDSjVEVCIsImlhdCI6MTcxMDg0Njc4MX0.yzj8qQ2eq28LoKSp2KAOb05MmDSooirEwVB9LCtoDjg"
def gov_request(id_set, params=None):
    url = "https://dados.gov.br/dados/api/publico/conjuntos-dados/" + id_set
    response = requests.get(url, params=params, headers = {"chave-api-dados-abertos" : key})
    
    if response.headers.get('content-type') != 'application/json':
        return print(response.headers.get('content-type'))

    return response.json()

# %%
import json
def read_json(file_path):
    with open(file_path, "r") as json_file:
        data = json.load(json_file)
    return data

# %% [markdown]
# ### Carrega catalogo

# %%
catalogo = read_json("../metadados/metadados_brutos/catalogos.json")

# %% [markdown]
# ### Carrega recursos

# %%
recurso = read_json("../metadados/metadados_brutos/recursos.json")

# %% [markdown]
# ## Estruturação dos metadados

# %% [markdown]
# ### Documents Catalogo

# %%
documents = []

[documents.append(

    {
    "id": doc['id'],
    "title": doc['title'],
    "nome": doc['nome'],
    'descricao': recurso[doc['id']]["descricao"],
    "catalogacao": doc['catalogacao'],
    "nomeOrganizacao": doc['nomeOrganizacao'],
    "ultimaAlteracaoMetadados": doc['ultimaAlteracaoMetadados'],
    "ultimaAtualizacaoDados": doc['ultimaAtualizacaoDados'],
    "isAtualizado": doc['isAtualizado'],
    }

) for doc in catalogo]
documents[0]
# Out:
# {'id': '3fc794a6-4217-4038-9b9d-b0ac7335efc3',
#  'title': '"Patrimônio Genético Nacional" que foram envolvidas em pesquisas realizadas na UFAM por ano',
#  'nome': 'patrimonio-genetico-nacional-que-foram-envolvidas-em-pesquisas-realizadas-na-ufam-por-ano',
#  'descricao': 'Relação das espécies do "Patrimônio Genético Nacional" que foram envolvidas em pesquisas realizadas na UFAM por ano',
#  'catalogacao': '08/02/2025 13:42:46',
#  'nomeOrganizacao': 'fundacao-universidade-do-amazonas',
#  'ultimaAlteracaoMetadados': '07/02/2025 19:59:50',
#  'ultimaAtualizacaoDados': '07/02/2025 19:59:50',
#  'isAtualizado': False}

# %% [markdown]
# ### Documents recursos

# %%
rec_documents = []
sem_recurso = []

for key in recurso:
    try:
        rec = recurso[key]['recursos'] # Retorna lista de recurso relativo a cada catalogo
        [rec_documents.append(r) for r in rec]
    except:
        sem_recurso.append(recurso[key])

rec_documents[0]
# Out:
# {'tamanho': 9505,
#  'dataCatalogacao': '07/02/2025',
#  'dataUltimaAtualizacaoArquivo': '07/02/2025',
#  'quantidadeDownloads': None,
#  'nomeArquivo': None,
#  'descricao': 'Relação das espécies do "Patrimônio Genético Nacional" que foram envolvidas em pesquisas realizadas na UFAM por ano',
#  'titulo': '"Patrimônio Genético Nacional" que foram envolvidas em pesquisas realizadas na UFAM por ano',
#  'formato': 'XLSX',
#  'tipo': None,
#  'numOrdem': None,
#  'idConjuntoDados': '3fc794a6-4217-4038-9b9d-b0ac7335efc3',
#  'link': 'https://dadosabertos.ufam.edu.br/dataset/3fc794a6-4217-4038-9b9d-b0ac7335efc3/resource/ac0e2b3e-d56d-4687-bda4-999720fa32e9/download/protec-4.xlsx',
#  'id': 'ac0e2b3e-d56d-4687-bda4-999720fa32e9'}

# %%
print(len(rec_documents))
rec_documents
# Out:
# 64201
# [{'tamanho': 9505,
#   'dataCatalogacao': '07/02/2025',
#   'dataUltimaAtualizacaoArquivo': '07/02/2025',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Relação das espécies do "Patrimônio Genético Nacional" que foram envolvidas em pesquisas realizadas na UFAM por ano',
#   'titulo': '"Patrimônio Genético Nacional" que foram envolvidas em pesquisas realizadas na UFAM por ano',
#   'formato': 'XLSX',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': '3fc794a6-4217-4038-9b9d-b0ac7335efc3',
#   'link': 'https://dadosabertos.ufam.edu.br/dataset/3fc794a6-4217-4038-9b9d-b0ac7335efc3/resource/ac0e2b3e-d56d-4687-bda4-999720fa32e9/download/protec-4.xlsx',
#   'id': 'ac0e2b3e-d56d-4687-bda4-999720fa32e9'},
#  {'tamanho': 0,
#   'dataCatalogacao': '25/06/2018',
#   'dataUltimaAtualizacaoArquivo': 'Indisponível (Resposta diferente do código 200)',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Lista os municípios que fazem parte da cobertura oferecida por plano de saúde de assistência médico-hospitalar, por operadora e por macrorregião. Os dados incluem apenas os planos criados após a Lei nº 9.656/1998, ou os planos a ela adaptados, que apresentem situação ativo ou ativo com comercialização suspensa no momento da extração dos dados.\r\n',
#   'titulo': 'Abrangência Geográfica dos Planos de Saúde',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': 'b866916e-3ac7-4173-af7d-3d8970072259',
#   'link': 'https://dadosabertos.ans.gov.br/FTP/PDA/area_atuacao_planos_saude/',
#   'id': '06012604-ccb9-4959-9424-18637d4dc42c'},
#  {'tamanho': 0,
#   'dataCatalogacao': '25/06/2018',
#   'dataUltimaAtualizacaoArquivo': 'Indisponível (Resposta diferente do código 200)',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Dicionário de Dados da Abrangência Geográfica dos Planos de Saúde.',
#   'titulo': 'Dicionário de Dados - Abrangência Geográfica dos Planos de Saúde',
#   'formato': 'PDF',
#   'tipo': 'DICIONARIO_DE_DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': 'b866916e-3ac7-4173-af7d-3d8970072259',
#   'link': 'https://dadosabertos.ans.gov.br/FTP/PDA/area_atuacao_planos_saude/dicionario_abrangencia_geografica.pdf',
#   'id': 'b5c7c6d7-447c-4ae3-9ded-2b0a8a4ad204'},
#  {'tamanho': 0,
#   'dataCatalogacao': '16/08/2022',
#   'dataUltimaAtualizacaoArquivo': '27/07/2023',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'A Portaria 1.510 de 21/08/2009 trazia a seguinte previsão: \nArt. 20. O empregador usuário do Sistema de Registro Eletrônico de Ponto deverá se cadastrar no MTE via internet informando seus dados, equipamentos e softwares utilizados \nA Portaria 671 de 08/11/2021 revogou a portaria 1510/2009. \nA nova portaria trouxe grande parte dos artigos da portaria antiga, essa obrigação específica não, então o empregador não tem mais a obrigação de cadastrar o seu equipamento REP no sistema CAREP. Diante disso, o sistema foi descontinuado (https://novocarep.mte.gov.br/) e não há mais essa informação ou atualização do conjunto de dados. Sendo assim, não é possível a retirada a lista dos REP cadastrados no referido sistema que eram disponibilizadas no endereço https://www.gov.br/trabalho-e-emprego/pt-br/assuntos/inspecao-do-trabalho/fiscalizacao-do-trabalho/rep.',
#   'titulo': 'Registradores Eletrônico de Ponto Convencional (REP-C)',
#   'formato': 'url',
#   'tipo': 'OUTRO',
#   'numOrdem': None,
#   'idConjuntoDados': '5ab40c59-6f45-44c9-8794-47ef9f2d6446',
#   'link': 'https://www.gov.br/trabalho-e-emprego/pt-br/assuntos/inspecao-do-trabalho/fiscalizacao-do-trabalho/rep',
#   'id': '22a4ed57-8d76-4f17-9067-a6a3eff5becc'},
#  {'tamanho': 0,
#   'dataCatalogacao': '01/08/2018',
#   'dataUltimaAtualizacaoArquivo': '31/08/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Fator que deve ser aplicado ao índice de reajuste estabelecido pela ANS, qual seja, o Índice de Preços ao Consumidor Amplo - IPCA, aplicável aos contratos entre os prestadores de serviços e as operadoras de planos de saúde, quando há previsão de livre negociação entre as partes, como única forma de reajuste, e não há acordo após a negociação, nos primeiros noventa dias do ano.\r\n\r\nOs critérios para aplicação do Fator de Qualidade seguem as diretrizes estabelecidas pela Instruções Normativas da DIDES/ANS de nº 61/2015 e n.º 63/2016, que complementam a regulamentação da Lei 13.003/2014, que alterou a Lei 9656/98, Lei dos planos de saúde. O Fator de Qualidade poderá ser de 105%, 100% ou 85% do IPCA a depender do cumprimento dos requisitos de qualidade previstos em Nota Técnica atualizada anualmente.\r\n\r\nSobre a descontinuação da atualização do conjunto de dados:\r\n\r\nAté 2017 a própria ANS levantava os dados e fazia o cálculo de quais prestadores deveriam fazer jus ao recebimento de cada um dos percentuais estabelecidos pela Resolução Normativa nº 364/2014.\r\n\r\nEm 2018, a ANS publicou uma alteração da RN 364 por meio da publicação da Resolução Normativa nº 436/2018, de acordo com os regramentos desse normativo, o fator de qualidade continua a ser um instrumento de reajuste a ser aplicado em casos específicos, porém, além de alterar os percentuais de aplicação do fator de qualidade, a norma estabelece que a verificação do cumprimento dos critérios para aplicação do Fator de Qualidade previstos no Anexo da RN deverá ser feita, a qualquer tempo no ano-base a ser considerado, diretamente pelas operadoras junto aos prestadores de serviço de assistência à saúde.\r\n\r\nDesta forma, a ANS deixa de ter a atribuição de verificar o cumprimento dos critérios e publicar os documentos com os prestadores que fariam jus aos percentuais específicos do Fator de Qualidade. Portanto, deixou de haver documentos a serem publicados no portal dados Abertos em função desta mudança no Normativo.\r\n',
#   'titulo': 'Fator de Qualidade - Hospitais - Dia 100%',
#   'formato': 'zip+csv',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': '2b18c3e2-0e3e-44a3-a435-5dc929877429',
#   'link': 'https://www.ans.gov.br/images/stories/Materiais_para_pesquisa/Perfil_setor/dados_abertos/hospitais_dia_100.zip',
#   'id': 'ed9a93e0-b8f1-4fd4-a4b8-898138a3acf3'},
#  {'tamanho': 0,
#   'dataCatalogacao': '01/08/2018',
#   'dataUltimaAtualizacaoArquivo': '23/08/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Fator de qualidade - Hospitais-Dia 100%',
#   'titulo': 'Dicionário de dados',
#   'formato': 'PDF',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': '2b18c3e2-0e3e-44a3-a435-5dc929877429',
#   'link': 'https://www.ans.gov.br/images/stories/Materiais_para_pesquisa/Perfil_setor/dados_abertos/dicionario_de_dados_fator_de_qualidade_hospital_dia_100.pdf',
#   'id': 'cf313f16-9eb7-4b96-bb69-63deb4990216'},
#  {'tamanho': 0,
#   'dataCatalogacao': '01/08/2018',
#   'dataUltimaAtualizacaoArquivo': '31/08/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Fator que deve ser aplicado ao índice de reajuste estabelecido pela ANS, qual seja, o Índice de Preços ao Consumidor Amplo - IPCA, aplicável aos contratos entre os prestadores de serviços e as operadoras de planos de saúde, quando há previsão de livre negociação entre as partes, como única forma de reajuste, e não há acordo após a negociação, nos primeiros noventa dias do ano.\r\n\r\nOs critérios para aplicação do Fator de Qualidade seguem as diretrizes estabelecidas pela Instruções Normativas da DIDES/ANS de nº 61/2015 e n.º 63/2016, que complementam a regulamentação da Lei 13.003/2014, que alterou a Lei 9656/98, Lei dos planos de saúde. O Fator de Qualidade poderá ser de 105%, 100% ou 85% do IPCA a depender do cumprimento dos requisitos de qualidade previstos em Nota Técnica atualizada anualmente.\r\n\r\nSobre a descontinuação da atualização do conjunto de dados:\r\n\r\nAté 2017 a própria ANS levantava os dados e fazia o cálculo de quais prestadores deveriam fazer jus ao recebimento de cada um dos percentuais estabelecidos pela Resolução Normativa nº 364/2014.\r\n\r\nEm 2018, a ANS publicou uma alteração da RN 364 por meio da publicação da Resolução Normativa nº 436/2018, de acordo com os regramentos desse normativo, o fator de qualidade continua a ser um instrumento de reajuste a ser aplicado em casos específicos, porém, além de alterar os percentuais de aplicação do fator de qualidade, a norma estabelece que a verificação do cumprimento dos critérios para aplicação do Fator de Qualidade previstos no Anexo da RN deverá ser feita, a qualquer tempo no ano-base a ser considerado, diretamente pelas operadoras junto aos prestadores de serviço de assistência à saúde.\r\n\r\nDesta forma, a ANS deixa de ter a atribuição de verificar o cumprimento dos critérios e publicar os documentos com os prestadores que fariam jus aos percentuais específicos do Fator de Qualidade. Portanto, deixou de haver documentos a serem publicados no portal dados Abertos em função desta mudança no Normativo.\r\n',
#   'titulo': 'Fator de Qualidade - Hospitais-Dia 105%',
#   'formato': 'zip+csv',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': 'ef402561-a74f-4e2c-ae74-c4ddd9b1e988',
#   'link': 'https://www.ans.gov.br/images/stories/Materiais_para_pesquisa/Perfil_setor/dados_abertos/hospitais_dia_105.zip',
#   'id': 'e383994e-64f4-49a2-a245-8447ad196698'},
#  {'tamanho': 0,
#   'dataCatalogacao': '01/08/2018',
#   'dataUltimaAtualizacaoArquivo': '23/08/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Fator de qualidade - Hospitais - Dia 105%',
#   'titulo': 'Dicionário de Dados',
#   'formato': 'PDF',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': 'ef402561-a74f-4e2c-ae74-c4ddd9b1e988',
#   'link': 'https://www.ans.gov.br/images/stories/Materiais_para_pesquisa/Perfil_setor/dados_abertos/dicionario_de_dados_fator_de_qualidade_hospital_dia_105.pdf',
#   'id': 'f899629b-d8b1-48fe-9674-44531fc585cd'},
#  {'tamanho': 0,
#   'dataCatalogacao': '23/05/2018',
#   'dataUltimaAtualizacaoArquivo': '22/05/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Os critérios para aplicação do Fator de Qualidade seguem as diretrizes estabelecidas pela Instruções Normativas ANS/DIDES nº 61/2015 e nº 63/2016, as quais complementam a regulamentação da Lei nº 13.003/2014, que alterou a Lei nº 9.656/98, Lei dos planos de saúde. O Fator de Qualidade poderá ser de 105%, 100% ou 85% do IPCA, a depender do cumprimento dos requisitos de qualidade previstos em Nota Técnica atualizada anualmente.\r\n\r\nSobre a descontinuação da atualização do conjunto de dados:\r\n\r\nAté 2017 a própria ANS levantava os dados e fazia o cálculo de quais prestadores deveriam fazer jus ao recebimento de cada um dos percentuais estabelecidos pela Resolução Normativa nº 364/2014.\r\n\r\nEm 2018, a ANS publicou uma alteração da RN 364 por meio da publicação da Resolução Normativa nº 436/2018, de acordo com os regramentos desse normativo, o fator de qualidade continua a ser um instrumento de reajuste a ser aplicado em casos específicos, porém, além de alterar os percentuais de aplicação do fator de qualidade, a norma estabelece que a verificação do cumprimento dos critérios para aplicação do Fator de Qualidade previstos no Anexo da RN deverá ser feita, a qualquer tempo no ano-base a ser considerado, diretamente pelas operadoras junto aos prestadores de serviço de assistência à saúde.\r\n\r\nDesta forma, a ANS deixa de ter a atribuição de verificar o cumprimento dos critérios e publicar os documentos com os prestadores que fariam jus aos percentuais específicos do Fator de Qualidade. Portanto, deixou de haver documentos a serem publicados no portal dados Abertos em função desta mudança no Normativo.',
#   'titulo': 'Fator de Qualidade - Profissionais 105%',
#   'formato': 'zip+csv',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': '8b73c869-56ad-456c-bb1f-21ede2269de6',
#   'link': 'https://www.ans.gov.br/images/stories/acessoainformacao/dados-abertos/pda_profissionais_105.zip',
#   'id': 'f6ada94c-dc24-4679-b234-b80ec371f26e'},
#  {'tamanho': 0,
#   'dataCatalogacao': '23/05/2018',
#   'dataUltimaAtualizacaoArquivo': '28/05/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Dicionário de Dados do Fator de Qualidade: Profissionais 105%.',
#   'titulo': 'Dicionário de Dados - Fator de Qualidade: Profissionais 105%',
#   'formato': 'PDF',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': '8b73c869-56ad-456c-bb1f-21ede2269de6',
#   'link': 'https://www.ans.gov.br/images/stories/acessoainformacao/dados-abertos/dicionario_de_dados_fq_profissionais_saude_105.pdf',
#   'id': '7a1cdd28-786e-42ec-8cfb-15d07b9e17dd'},
#  {'tamanho': 0,
#   'dataCatalogacao': '01/08/2018',
#   'dataUltimaAtualizacaoArquivo': '31/08/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Fator que deve ser aplicado ao índice de reajuste estabelecido pela ANS, qual seja, o Índice de Preços ao Consumidor Amplo - IPCA, aplicável aos contratos entre os prestadores de serviços e as operadoras de planos de saúde, quando há previsão de livre negociação entre as partes, como única forma de reajuste, e não há acordo após a negociação, nos primeiros noventa dias do ano.\r\n\r\nOs critérios para aplicação do Fator de Qualidade seguem as diretrizes estabelecidas pela Instruções Normativas da DIDES/ANS de nº 61/2015 e n.º 63/2016, que complementam a regulamentação da Lei 13.003/2014, que alterou a Lei 9656/98, Lei dos planos de saúde. O Fator de Qualidade poderá ser de 105%, 100% ou 85% do IPCA a depender do cumprimento dos requisitos de qualidade previstos em Nota Técnica atualizada anualmente.\r\n\r\nSobre a descontinuação da atualização do conjunto de dados:\r\n\r\nAté 2017 a própria ANS levantava os dados e fazia o cálculo de quais prestadores deveriam fazer jus ao recebimento de cada um dos percentuais estabelecidos pela Resolução Normativa nº 364/2014.\r\n\r\nEm 2018, a ANS publicou uma alteração da RN 364 por meio da publicação da Resolução Normativa nº 436/2018, de acordo com os regramentos desse normativo, o fator de qualidade continua a ser um instrumento de reajuste a ser aplicado em casos específicos, porém, além de alterar os percentuais de aplicação do fator de qualidade, a norma estabelece que a verificação do cumprimento dos critérios para aplicação do Fator de Qualidade previstos no Anexo da RN deverá ser feita, a qualquer tempo no ano-base a ser considerado, diretamente pelas operadoras junto aos prestadores de serviço de assistência à saúde.\r\n\r\nDesta forma, a ANS deixa de ter a atribuição de verificar o cumprimento dos critérios e publicar os documentos com os prestadores que fariam jus aos percentuais específicos do Fator de Qualidade. Portanto, deixou de haver documentos a serem publicados no portal dados Abertos em função desta mudança no Normativo.\r\n\r\n',
#   'titulo': 'Fator de Qualidade - SADT 100%',
#   'formato': 'zip+csv',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': 'c4877784-dd9c-46f3-b213-a5cd3072da07',
#   'link': 'https://www.ans.gov.br/images/stories/Materiais_para_pesquisa/Perfil_setor/dados_abertos/sadt_100.zip',
#   'id': '4e545eba-1ee2-49be-97f3-a5344fb713a9'},
#  {'tamanho': 0,
#   'dataCatalogacao': '01/08/2018',
#   'dataUltimaAtualizacaoArquivo': '23/08/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Fator de Qualidade - SADT 100%',
#   'titulo': 'Dicionário de Dados',
#   'formato': 'PDF',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': 'c4877784-dd9c-46f3-b213-a5cd3072da07',
#   'link': 'https://www.ans.gov.br/images/stories/Materiais_para_pesquisa/Perfil_setor/dados_abertos/dicionario_de_dados_fator_de_qualidade_sadt_100.pdf',
#   'id': '03b1a813-2f45-4113-a4cb-fe1aae9433a4'},
#  {'tamanho': 0,
#   'dataCatalogacao': '01/08/2018',
#   'dataUltimaAtualizacaoArquivo': '31/08/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Fator que deve ser aplicado ao índice de reajuste estabelecido pela ANS, qual seja, o Índice de Preços ao Consumidor Amplo - IPCA, aplicável aos contratos entre os prestadores de serviços e as operadoras de planos de saúde, quando há previsão de livre negociação entre as partes, como única forma de reajuste, e não há acordo após a negociação, nos primeiros noventa dias do ano.\r\n\r\nOs critérios para aplicação do Fator de Qualidade seguem as diretrizes estabelecidas pela Instruções Normativas da DIDES/ANS de nº 61/2015 e n.º 63/2016, que complementam a regulamentação da Lei 13.003/2014, que alterou a Lei 9656/98, Lei dos planos de saúde. O Fator de Qualidade poderá ser de 105%, 100% ou 85% do IPCA a depender do cumprimento dos requisitos de qualidade previstos em Nota Técnica atualizada anualmente.\r\n\r\nSobre a descontinuação da atualização do conjunto de dados:\r\n\r\nAté 2017 a própria ANS levantava os dados e fazia o cálculo de quais prestadores deveriam fazer jus ao recebimento de cada um dos percentuais estabelecidos pela Resolução Normativa nº 364/2014.\r\n\r\nEm 2018, a ANS publicou uma alteração da RN 364 por meio da publicação da Resolução Normativa nº 436/2018, de acordo com os regramentos desse normativo, o fator de qualidade continua a ser um instrumento de reajuste a ser aplicado em casos específicos, porém, além de alterar os percentuais de aplicação do fator de qualidade, a norma estabelece que a verificação do cumprimento dos critérios para aplicação do Fator de Qualidade previstos no Anexo da RN deverá ser feita, a qualquer tempo no ano-base a ser considerado, diretamente pelas operadoras junto aos prestadores de serviço de assistência à saúde.\r\n\r\nDesta forma, a ANS deixa de ter a atribuição de verificar o cumprimento dos critérios e publicar os documentos com os prestadores que fariam jus aos percentuais específicos do Fator de Qualidade. Portanto, deixou de haver documentos a serem publicados no portal dados Abertos em função desta mudança no Normativo.\r\n',
#   'titulo': 'Fator de Qualidade - SADT 105%',
#   'formato': 'zip+csv',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': '7eb60cb7-eadb-44ee-83e2-44e3db150d2a',
#   'link': 'https://www.ans.gov.br/images/stories/Materiais_para_pesquisa/Perfil_setor/dados_abertos/sadt_105.zip',
#   'id': '56c1cdc0-c1f1-4b1a-96cc-5d0534ef2dfe'},
#  {'tamanho': 0,
#   'dataCatalogacao': '01/08/2018',
#   'dataUltimaAtualizacaoArquivo': '23/08/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Fator de Qualidade - SADT 105%',
#   'titulo': 'Dicionário de Dados',
#   'formato': 'PDF',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': '7eb60cb7-eadb-44ee-83e2-44e3db150d2a',
#   'link': 'https://www.ans.gov.br/images/stories/Materiais_para_pesquisa/Perfil_setor/dados_abertos/dicionario_de_dados_fator_de_qualidade_sadt_105.pdf',
#   'id': '87b6a27e-3a03-4c82-8f3e-e2698b75c7da'},
#  {'tamanho': 0,
#   'dataCatalogacao': '23/05/2018',
#   'dataUltimaAtualizacaoArquivo': '22/05/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Os critérios para aplicação do Fator de Qualidade seguem as diretrizes estabelecidas pela Instruções Normativas ANS/DIDES nº 61/2015 e nº 63/2016, as quais complementam a regulamentação da Lei nº 13.003/2014, que alterou a Lei nº 9.656/98, Lei dos planos de saúde. O Fator de Qualidade poderá ser de 105%, 100% ou 85% do IPCA, a depender do cumprimento dos requisitos de qualidade previstos em Nota Técnica atualizada anualmente\r\n\r\n\r\nSobre a descontinuação da atualização do conjunto de dados:\r\n\r\nAté 2017 a própria ANS levantava os dados e fazia o cálculo de quais prestadores deveriam fazer jus ao recebimento de cada um dos percentuais estabelecidos pela Resolução Normativa nº 364/2014.\r\n\r\nEm 2018, a ANS publicou uma alteração da RN 364 por meio da publicação da Resolução Normativa nº 436/2018, de acordo com os regramentos desse normativo, o fator de qualidade continua a ser um instrumento de reajuste a ser aplicado em casos específicos, porém, além de alterar os percentuais de aplicação do fator de qualidade, a norma estabelece que a verificação do cumprimento dos critérios para aplicação do Fator de Qualidade previstos no Anexo da RN deverá ser feita, a qualquer tempo no ano-base a ser considerado, diretamente pelas operadoras junto aos prestadores de serviço de assistência à saúde.\r\n\r\nDesta forma, a ANS deixa de ter a atribuição de verificar o cumprimento dos critérios e publicar os documentos com os prestadores que fariam jus aos percentuais específicos do Fator de Qualidade. Portanto, deixou de haver documentos a serem publicados no portal dados Abertos em função desta mudança no Normativo.',
#   'titulo': 'Fator de qualidade - Hospitais 100%',
#   'formato': 'zip+csv',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': '10fa8132-b4c5-4ff1-99e8-dd08b44e8f38',
#   'link': 'https://www.ans.gov.br/images/stories/acessoainformacao/dados-abertos/pda_hospital_100.zip',
#   'id': 'ef1fe459-bfc1-4566-83ed-0c70a0208772'},
#  {'tamanho': 0,
#   'dataCatalogacao': '23/05/2018',
#   'dataUltimaAtualizacaoArquivo': '28/05/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Dicionário de Dados do Fator de Qualidade - Hospitais 100%.',
#   'titulo': 'Dicionário de Dados - Fator de qualidade: Hospitais 100%',
#   'formato': 'PDF',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': '10fa8132-b4c5-4ff1-99e8-dd08b44e8f38',
#   'link': 'https://www.ans.gov.br/images/stories/acessoainformacao/dados-abertos/dicionario_de_dados_fq_hospitais_100.pdf',
#   'id': 'f39949ab-02b3-4fc4-a2d6-a4a202816100'},
#  {'tamanho': 0,
#   'dataCatalogacao': '24/05/2018',
#   'dataUltimaAtualizacaoArquivo': '22/05/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Os critérios para aplicação do Fator de Qualidade seguem as diretrizes estabelecidas pela Instruções Normativas ANS/DIDES nº 61/2015 e nº 63/2016, as quais complementam a regulamentação da Lei nº 13.003/2014, que alterou a Lei nº 9.656/98, Lei dos planos de saúde. O Fator de Qualidade poderá ser de 105%, 100% ou 85% do IPCA, a depender do cumprimento dos requisitos de qualidade previstos em Nota Técnica atualizada anualmente.\r\n\r\nSobre a descontinuação da atualização do conjunto de dados:\r\n\r\nAté 2017 a própria ANS levantava os dados e fazia o cálculo de quais prestadores deveriam fazer jus ao recebimento de cada um dos percentuais estabelecidos pela Resolução Normativa nº 364/2014.\r\n\r\nEm 2018, a ANS publicou uma alteração da RN 364 por meio da publicação da Resolução Normativa nº 436/2018, de acordo com os regramentos desse normativo, o fator de qualidade continua a ser um instrumento de reajuste a ser aplicado em casos específicos, porém, além de alterar os percentuais de aplicação do fator de qualidade, a norma estabelece que a verificação do cumprimento dos critérios para aplicação do Fator de Qualidade previstos no Anexo da RN deverá ser feita, a qualquer tempo no ano-base a ser considerado, diretamente pelas operadoras junto aos prestadores de serviço de assistência à saúde.\r\n\r\nDesta forma, a ANS deixa de ter a atribuição de verificar o cumprimento dos critérios e publicar os documentos com os prestadores que fariam jus aos percentuais específicos do Fator de Qualidade. Portanto, deixou de haver documentos a serem publicados no portal dados Abertos em função desta mudança no Normativo.\r\n',
#   'titulo': 'Fator de Qualidade - Hospitais 105%',
#   'formato': 'zip+csv',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': '7e51bf80-03f5-4cf4-bac2-9c179c3c36c6',
#   'link': 'https://www.ans.gov.br/images/stories/acessoainformacao/dados-abertos/pda_hospital_105.zip',
#   'id': '8da76af9-7ba1-4eac-881a-7302c7d5f03a'},
#  {'tamanho': 0,
#   'dataCatalogacao': '24/05/2018',
#   'dataUltimaAtualizacaoArquivo': '28/05/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Dicionário de Dados do Fator de Qualidade - Hospitais 105%.',
#   'titulo': 'Dicionário de Dados - Fator de Qualidade: Hospitais 105%',
#   'formato': 'PDF',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': '7e51bf80-03f5-4cf4-bac2-9c179c3c36c6',
#   'link': 'https://www.ans.gov.br/images/stories/acessoainformacao/dados-abertos/dicionario_de_dados_fq_hospitais_105.pdf',
#   'id': '67c2e60e-9919-4e33-9a37-925909dcbb81'},
#  {'tamanho': 0,
#   'dataCatalogacao': '22/05/2018',
#   'dataUltimaAtualizacaoArquivo': '22/05/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Os critérios para aplicação do Fator de Qualidade seguem as diretrizes estabelecidas pelas Instruções Normativas ANS/DIDES nº 61/2015 e nº 63/2016, as quais complementam a regulamentação da Lei nº 13.003/2014, que alterou a Lei nº 9.656/98, Lei dos planos de saúde. O Fator de Qualidade poderá ser de 105%, 100% ou 85% do IPCA, a depender do cumprimento dos requisitos de qualidade previstos em Nota Técnica atualizada anualmente.\r\n\r\nSobre a descontinuação da atualização do conjunto de dados:\r\n\r\nAté 2017 a própria ANS levantava os dados e fazia o cálculo de quais prestadores deveriam fazer jus ao recebimento de cada um dos percentuais estabelecidos pela Resolução Normativa nº 364/2014.\r\n\r\nEm 2018, a ANS publicou uma alteração da RN 364 por meio da publicação da Resolução Normativa nº 436/2018, de acordo com os regramentos desse normativo, o fator de qualidade continua a ser um instrumento de reajuste a ser aplicado em casos específicos, porém, além de alterar os percentuais de aplicação do fator de qualidade, a norma estabelece que a verificação do cumprimento dos critérios para aplicação do Fator de Qualidade previstos no Anexo da RN deverá ser feita, a qualquer tempo no ano-base a ser considerado, diretamente pelas operadoras junto aos prestadores de serviço de assistência à saúde.\r\nDesta forma, a ANS deixa de ter a atribuição de verificar o cumprimento dos critérios e publicar os documentos com os prestadores que fariam jus aos percentuais específicos do Fator de Qualidade. Portanto, deixou de haver documentos a serem publicados no portal dados Abertos em função desta mudança no Normativo.',
#   'titulo': 'Fator de qualidade - Profissionais 100%',
#   'formato': 'zip+csv',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': 'f2f74747-51dc-4313-90f5-40c48030bf87',
#   'link': 'https://www.ans.gov.br/images/stories/acessoainformacao/dados-abertos/pda_profissionais_100.zip',
#   'id': '1f390326-d572-42e9-9b4f-86d0e8f98197'},
#  {'tamanho': 0,
#   'dataCatalogacao': '22/05/2018',
#   'dataUltimaAtualizacaoArquivo': '28/05/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Dicionário de Dados do Fator de Qualidade - Profissionais 100%.',
#   'titulo': 'Dicionário de Dados - Fator de Qualidade: Profissionais 100%',
#   'formato': 'PDF',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': 'f2f74747-51dc-4313-90f5-40c48030bf87',
#   'link': 'https://www.ans.gov.br/images/stories/acessoainformacao/dados-abertos/dicionario_de_dados_fq_profissionais_saude_100.pdf',
#   'id': 'b08119f4-45cd-42d5-abf9-4125884e9c9a'},
#  {'tamanho': 0,
#   'dataCatalogacao': '25/06/2018',
#   'dataUltimaAtualizacaoArquivo': '08/07/2020',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Apresenta os vocábulos da saúde suplementar, suas definições, suas referências, seus sinônimos e suas traduções.\r\n',
#   'titulo': 'Glossário da Saúde Suplementar',
#   'formato': 'zip+csv',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': '19226124-664e-4e80-856f-76240e83700f',
#   'link': 'https://dadosabertos.ans.gov.br/FTP/PDA/glossario_saude_suplementar/glossário_2020.ods',
#   'id': '0016f01e-44c0-4927-8874-4059210b57c0'},
#  {'tamanho': 0,
#   'dataCatalogacao': '25/06/2018',
#   'dataUltimaAtualizacaoArquivo': '25/06/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Dicionário de Dados da Glossário da Saúde Suplementar.',
#   'titulo': 'Dicionário de Dados - Glossário da Saúde Suplementar',
#   'formato': 'PDF',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': '19226124-664e-4e80-856f-76240e83700f',
#   'link': 'https://www.ans.gov.br/images/stories/Materiais_para_pesquisa/Perfil_setor/dados_abertos/glossario_ss/dicionario_glossario_ss.pdf',
#   'id': '18cbcde7-9619-484a-b2bc-948eea90f001'},
#  {'tamanho': 0,
#   'dataCatalogacao': '24/08/2017',
#   'dataUltimaAtualizacaoArquivo': '25/05/2017',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': '\r\n\r\nO índice de reclamação tem atualização mensal e seus indicadores têm como base os dados de beneficiários e reclamações, por temas, recebidos pela ANS nos três meses anteriores.\r\n\r\nO índice Geral de Reclamações (IGR) contempla o número médio de reclamações de beneficiários recebidas nos três meses anteriores e classificadas até a data de extração do dado. O índice tem como referência cada 10.000 beneficiários do universo de consumidores analisado. Quanto menor o índice melhor a classificação das operadoras.\r\n\r\nO Percentual de Finalização Assistencial (PFA) considera o total de reclamações de natureza assistencial solucionadas pela mediação de conflitos por meio da Notificação de Intermediação Preliminar (NIP). Quando maior o percentual, melhor a classificação das operadoras.\r\n\r\nO índice de Abertura de Processo Administrativo (IAP) é um indicador complementar ao IGR e ao PFA, que considera o volume de reclamações com indício de infração que foram encaminhadas para os Núcleos da ANS para abertura de processo administrativo visando a sua apuração. Quanto menor o índice melhor a classificação das operadoras.\r\n',
#   'titulo': 'Ficha Técnica do Índice de Reclamações',
#   'formato': 'PDF',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': 'f2041210-17b6-4a4c-bfa7-561e5093f6fe',
#   'link': 'https://www.ans.gov.br/images/stories/Plano_de_saude_e_Operadoras/informacoes_avaliacoes/IR2015/fichas-nova-metodologia.pdf',
#   'id': 'bd49471d-51c2-41d5-ac52-21653b22f734'},
#  {'tamanho': 0,
#   'dataCatalogacao': '24/08/2017',
#   'dataUltimaAtualizacaoArquivo': '18/11/2022',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': '< DADOS EM MANUTENÇÃO>\n\nO PFA considera o total de reclamações de natureza assistencial solucionadas pela mediação de conflitos por meio da Notificação de Intermediação Preliminar (NIP). Quando maior o percentual, melhor a classificação das operadoras.',
#   'titulo': 'Percentual de Finalização Assistencial',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': 'f2041210-17b6-4a4c-bfa7-561e5093f6fe',
#   'link': 'https://dadosabertos.ans.gov.br/FTP/PDA/PFA/pfa.csv',
#   'id': '3dd4e115-f8b1-4f6c-99c9-b80786f6b35b'},
#  {'tamanho': 0,
#   'dataCatalogacao': '24/08/2017',
#   'dataUltimaAtualizacaoArquivo': '24/08/2017',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': '< DADOS EM MANUTENÇÃO>\n\nO Percentual de Finalização Assistencial (PFA) considera o total de reclamações de natureza assistencial solucionadas pela mediação de conflitos por meio da Notificação de Intermediação Preliminar (NIP). Quando maior o percentual, melhor a classificação das operadoras.',
#   'titulo': 'Dicionário de Dados _ PFA',
#   'formato': 'PDF',
#   'tipo': 'DICIONARIO_DE_DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': 'f2041210-17b6-4a4c-bfa7-561e5093f6fe',
#   'link': 'https://www.ans.gov.br/images/stories/Materiais_para_pesquisa/Perfil_setor/dados_abertos/dicionario_dados_abertos_ANS_PFA.pdf',
#   'id': '924d9180-c032-4b97-89f9-3469728a5897'},
#  {'tamanho': 0,
#   'dataCatalogacao': '24/08/2017',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': '< DADOS EM MANUTENÇÃO>\n\nDados de reclamações de beneficiários atualizados mensalmente a partir de demandas dos últimos três meses. A cada novo processamento existe a possibilidade de revisão dos índices já divulgados em razão de ajustes no número de beneficiários e de eventuais reclassificações no status das demandas NIP (Notificação de Intermediação Preliminar).',
#   'titulo': 'Dados gerais das reclamações',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': 'f2041210-17b6-4a4c-bfa7-561e5093f6fe',
#   'link': 'https://dadosabertos.ans.gov.br/FTP/PDA/IGR/dados-gerais-das-reclamacoes/',
#   'id': '77bff06f-9fe4-4904-9bd4-c5eb5ed3047b'},
#  {'tamanho': 0,
#   'dataCatalogacao': '24/08/2017',
#   'dataUltimaAtualizacaoArquivo': '22/08/2017',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': '< DADOS EM MANUTENÇÃO>\n\nDados de reclamações de beneficiários atualizados mensalmente a partir de demandas dos últimos três meses. A cada novo processamento existe a possibilidade de revisão dos índices já divulgados em razão de ajustes no número de beneficiários e de eventuais reclassificações no status das demandas NIP (Notificação de Intermediação Preliminar).',
#   'titulo': 'Dicionário de dados_Dados gerais das reclamações ',
#   'formato': 'PDF',
#   'tipo': 'DICIONARIO_DE_DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': 'f2041210-17b6-4a4c-bfa7-561e5093f6fe',
#   'link': 'https://www.ans.gov.br/images/stories/Materiais_para_pesquisa/Perfil_setor/dados_abertos/dicionario_dados_abertos_ANS_Dados_Gerais_das_reclamacoes_por_operadora.pdf',
#   'id': '347fa2af-2cee-43ff-a75d-cd3b31a7752e'},
#  {'tamanho': 0,
#   'dataCatalogacao': '25/04/2018',
#   'dataUltimaAtualizacaoArquivo': '29/04/2020',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Trata-se de uma pasta compactada na qual estão inseridos arquivos no formato .csv, cada um dos quais se refere ao resultado anual do PQI, a partir de 2008.',
#   'titulo': 'Programa de Qualificação Institucional (histórico de resultados)',
#   'formato': 'zip+csv',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': '912d31f5-c790-4597-b0fa-89a657f33214',
#   'link': 'https://dadosabertos.ans.gov.br/FTP/PDA/programa_de_qualificacao_institucional/programa_qualificacao_institucional.zip',
#   'id': '008eda03-61ba-4b5f-97f1-304c1e65fafb'},
#  {'tamanho': 0,
#   'dataCatalogacao': '25/04/2018',
#   'dataUltimaAtualizacaoArquivo': '27/05/2019',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Dicionário de dados do PQI.',
#   'titulo': 'Dicionário de Dados - Programa de Qualificação Institucional (histórico de resultados)',
#   'formato': 'ODS',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': '912d31f5-c790-4597-b0fa-89a657f33214',
#   'link': 'https://dadosabertos.ans.gov.br/FTP/PDA/programa_de_qualificacao_institucional/dicionario_programa_qualificacao_institucional.ods',
#   'id': 'f2e31bb9-ec36-4358-9787-3aa5764be2a5'},
#  {'tamanho': 0,
#   'dataCatalogacao': '17/08/2017',
#   'dataUltimaAtualizacaoArquivo': '25/05/2017',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'O índice de reclamação tem atualização mensal e seus indicadores têm como base os dados de beneficiários e reclamações, por temas, recebidos pela ANS nos três meses anteriores.\n\nO índice Geral de Reclamações (IGR) contempla o número médio de reclamações de beneficiários recebidas nos três meses anteriores e classificadas até a data de extração do dado. O índice tem como referência cada 10.000 beneficiários do universo de consumidores analisado. Quanto menor o índice melhor a classificação das operadoras.',
#   'titulo': 'Ficha Técnica do Índice de Reclamações',
#   'formato': 'PDF',
#   'tipo': 'DOCUMENTACAO',
#   'numOrdem': None,
#   'idConjuntoDados': '6f8af764-243f-4662-8038-5c8bf7e9db7b',
#   'link': 'https://www.ans.gov.br/images/stories/Plano_de_saude_e_Operadoras/informacoes_avaliacoes/IR2015/fichas-nova-metodologia.pdf',
#   'id': '0067ab30-bf4e-49f5-973d-5d0b13919f5a'},
#  {'tamanho': 0,
#   'dataCatalogacao': '17/08/2017',
#   'dataUltimaAtualizacaoArquivo': '18/11/2022',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'O índice Geral de Reclamações (IGR) contempla o número médio de reclamações de beneficiários recebidas nos três meses anteriores e classificadas até a data de extração do dado. O índice tem como referência cada 10.000 beneficiários do universo de consumidores analisado. Quanto menor o índice melhor a classificação das operadoras.',
#   'titulo': 'Índice Geral de Reclamações',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '6f8af764-243f-4662-8038-5c8bf7e9db7b',
#   'link': 'https://dadosabertos.ans.gov.br/FTP/PDA/IGR/igr.csv',
#   'id': '24a4c16e-0708-4827-b744-87e16e4d0df7'},
#  {'tamanho': 0,
#   'dataCatalogacao': '22/08/2017',
#   'dataUltimaAtualizacaoArquivo': '24/08/2017',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'dicionário de dados do IGR',
#   'titulo': 'Dicionário de Dados _ IGR',
#   'formato': 'PDF',
#   'tipo': 'DICIONARIO_DE_DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '6f8af764-243f-4662-8038-5c8bf7e9db7b',
#   'link': 'https://www.ans.gov.br/images/stories/Materiais_para_pesquisa/Perfil_setor/dados_abertos/dicionario_dados_abertos_ANS_IGR.pdf',
#   'id': '3bb8f6c8-f566-489e-aa2b-66c0589809ec'},
#  {'tamanho': 0,
#   'dataCatalogacao': '17/08/2017',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Dados de reclamações de beneficiários atualizados mensalmente a partir de demandas dos últimos três meses. A cada novo processamento existe a possibilidade de revisão dos índices já  divulgados em razão de ajustes no número de beneficiários e de eventuais reclassificações no status das demandas NIP (Notificação de Intermediação Preliminar).DAD',
#   'titulo': 'Dados gerais das reclamações',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '6f8af764-243f-4662-8038-5c8bf7e9db7b',
#   'link': 'https://dadosabertos.ans.gov.br/FTP/PDA/IGR/dados-gerais-das-reclamacoes/',
#   'id': 'e2ce8bdb-895a-497f-acad-463a429f5104'},
#  {'tamanho': 0,
#   'dataCatalogacao': '22/08/2017',
#   'dataUltimaAtualizacaoArquivo': '22/08/2017',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Dados de reclamações de beneficiários atualizados mensalmente a partir de demandas dos últimos três meses. A cada novo processamento existe a possibilidade de revisão dos índices já divulgados em razão de ajustes no número de beneficiários e de eventuais reclassificações no status das demandas NIP (Notificação de Intermediação Preliminar).',
#   'titulo': 'Dicionário de dados_Dados gerais das reclamações ',
#   'formato': 'PDF',
#   'tipo': 'DICIONARIO_DE_DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '6f8af764-243f-4662-8038-5c8bf7e9db7b',
#   'link': 'https://www.ans.gov.br/images/stories/Materiais_para_pesquisa/Perfil_setor/dados_abertos/dicionario_dados_abertos_ANS_Dados_Gerais_das_reclamacoes_por_operadora.pdf',
#   'id': '98a6f1eb-0dce-4982-9936-1c6219f9a7db'},
#  {'tamanho': 0,
#   'dataCatalogacao': '22/06/2018',
#   'dataUltimaAtualizacaoArquivo': '21/11/2022',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'São disponibilizados os dados calculados mensalmente (congelado) a partir de 2015.',
#   'titulo': ' Índice Geral de Reclamações - ANUAL',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '6f8af764-243f-4662-8038-5c8bf7e9db7b',
#   'link': 'https://dadosabertos.ans.gov.br/FTP/PDA/IGR/igr_anual.zip',
#   'id': 'c6332d27-bffe-43bf-a678-7331dffba53f'},
#  {'tamanho': 0,
#   'dataCatalogacao': '22/06/2018',
#   'dataUltimaAtualizacaoArquivo': '21/06/2018',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Dicionário IGR anual',
#   'titulo': 'Dicionário de Dados _ IGR - ANUAL',
#   'formato': 'PDF',
#   'tipo': 'DICIONARIO_DE_DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '6f8af764-243f-4662-8038-5c8bf7e9db7b',
#   'link': 'https://www.ans.gov.br/images/stories/Materiais_para_pesquisa/Perfil_setor/dados_abertos/igr_anual/igr_anual_dicionario.pdf',
#   'id': 'c621fc2d-a4e6-43b3-afb4-9143c36f4d6c'},
#  {'tamanho': 0,
#   'dataCatalogacao': '24/08/2017',
#   'dataUltimaAtualizacaoArquivo': '25/05/2017',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'O índice de reclamação tem atualização mensal e seus indicadores têm como base os dados de beneficiários e reclamações, por temas, recebidos pela ANS nos três meses anteriores.\r\n\r\nO índice Geral de Reclamações (IGR) contempla o número médio de reclamações de beneficiários recebidas nos três meses anteriores e classificadas até a data de extração do dado. O índice tem como referência cada 10.000 beneficiários do universo de consumidores analisado. Quanto menor o índice melhor a classificação das operadoras.\r\n\r\nO Percentual de Finalização Assistencial (PFA) considera o total de reclamações de natureza assistencial solucionadas pela mediação de conflitos por meio da Notificação de Intermediação Preliminar (NIP). Quando maior o percentual, melhor a classificação das operadoras.\r\n\r\nO índice de Abertura de Processo Administrativo (IAP) é um indicador complementar ao IGR e ao PFA, que considera o volume de reclamações com indício de infração que foram encaminhadas para os Núcleos da ANS para abertura de processo administrativo visando a sua apuração.  Quanto menor o índice melhor a classificação das operadoras.\r\n',
#   'titulo': 'Ficha Técnica do Índice de Reclamações',
#   'formato': 'PDF',
#   'tipo': None,
#   'numOrdem': None,
#   'idConjuntoDados': 'b854cc09-5ee3-4c35-9a4e-a00bb62f176e',
#   'link': 'https://www.ans.gov.br/images/stories/Plano_de_saude_e_Operadoras/informacoes_avaliacoes/IR2015/fichas-nova-metodologia.pdf',
#   'id': '79ace5d2-ac14-4bc4-9d36-6c505d5fa631'},
#  {'tamanho': 0,
#   'dataCatalogacao': '24/08/2017',
#   'dataUltimaAtualizacaoArquivo': '18/11/2022',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': '< DADOS EM MANUTENÇÃO>\n\nO índice de Abertura de Processo Administrativo (IAP) é um indicador complementar ao IGR e PFA, que considera o volume de reclamações com indício de infração que foram encaminhadas para os Núcleos da ANS para abertura de processo administrativo visando a sua apuração. Quanto menor o índice melhor a classificação das operadoras.',
#   'titulo': 'Índice de Abertura de Processo Administrativo',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': 'b854cc09-5ee3-4c35-9a4e-a00bb62f176e',
#   'link': 'https://dadosabertos.ans.gov.br/FTP/PDA/IAP/iap.csv',
#   'id': '7e8fef4f-09fb-4880-b713-d0bd1bcfdb2c'},
#  {'tamanho': 0,
#   'dataCatalogacao': '24/08/2017',
#   'dataUltimaAtualizacaoArquivo': '24/08/2017',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': '< DADOS EM MANUTENÇÃO>\n\nO índice de Abertura de Processo Administrativo (IAP) é um indicador complementar ao IGR e PFA, que considera o volume de reclamações com indício de infração que foram encaminhadas para os Núcleos da ANS para abertura de processo administrativo visando a sua apuração. Quanto menor o índice melhor a classificação das operadoras.',
#   'titulo': 'Dicionário de dados _ IAP',
#   'formato': 'PDF',
#   'tipo': 'DICIONARIO_DE_DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': 'b854cc09-5ee3-4c35-9a4e-a00bb62f176e',
#   'link': 'https://www.ans.gov.br/images/stories/Materiais_para_pesquisa/Perfil_setor/dados_abertos/dicionario_dados_abertos_ANS_IAP.pdf',
#   'id': '786618d8-4668-4830-8c50-5dc485421edd'},
#  {'tamanho': 0,
#   'dataCatalogacao': '24/08/2017',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': '< DADOS EM MANUTENÇÃO>\n\nDados de reclamações de beneficiários atualizados mensalmente a partir de demandas dos últimos três meses. A cada novo processamento existe a possibilidade de revisão dos índices já  divulgados em razão de ajustes no número de beneficiários e de eventuais reclassificações no status das demandas NIP (Notificação de Intermediação Preliminar).',
#   'titulo': 'Dados gerais das reclamações',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': 'b854cc09-5ee3-4c35-9a4e-a00bb62f176e',
#   'link': 'https://dadosabertos.ans.gov.br/FTP/PDA/IGR/dados-gerais-das-reclamacoes/',
#   'id': '0128b4f8-d877-4cb6-9b91-bcbce23dcc87'},
#  {'tamanho': 0,
#   'dataCatalogacao': '24/08/2017',
#   'dataUltimaAtualizacaoArquivo': '22/08/2017',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': '< DADOS EM MANUTENÇÃO>\n\nDados de reclamações de beneficiários atualizados mensalmente a partir de demandas dos últimos três meses. A cada novo processamento existe a possibilidade de revisão dos índices já divulgados em razão de ajustes no número de beneficiários e de eventuais reclassificações no status das demandas NIP (Notificação de Intermediação Preliminar).',
#   'titulo': 'Dicionário de dados_Dados gerais das reclamações ',
#   'formato': 'PDF',
#   'tipo': 'DICIONARIO_DE_DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': 'b854cc09-5ee3-4c35-9a4e-a00bb62f176e',
#   'link': 'https://www.ans.gov.br/images/stories/Materiais_para_pesquisa/Perfil_setor/dados_abertos/dicionario_dados_abertos_ANS_Dados_Gerais_das_reclamacoes_por_operadora.pdf',
#   'id': '94ccfbff-3869-4f00-957a-54235499f4f0'},
#  {'tamanho': 0,
#   'dataCatalogacao': '29/01/2024',
#   'dataUltimaAtualizacaoArquivo': '22/01/2024',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Relação de comissões institucionais permanentes.',
#   'titulo': '01. Comissões Institucionais Permanentes',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '6162d5bd-e6d8-4a2e-b4d7-339356c2b167',
#   'link': 'https://www.gov.br/ebserh/pt-br/hospitais-universitarios/regiao-nordeste/huol-ufrn/acesso-a-informacao/dados-abertos-1/SEGOV/01-comissoes-institucionais-permanentes-referencia_-ano-de-2023.csv/view',
#   'id': '5c7d4d67-1f67-4ba3-a0ce-a82e387a7897'},
#  {'tamanho': 0,
#   'dataCatalogacao': '29/01/2024',
#   'dataUltimaAtualizacaoArquivo': '22/01/2024',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Relação de comissões institucionais permanentes.',
#   'titulo': '01. Comissões Institucionais Permanentes',
#   'formato': 'PDF',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '6162d5bd-e6d8-4a2e-b4d7-339356c2b167',
#   'link': 'https://www.gov.br/ebserh/pt-br/hospitais-universitarios/regiao-nordeste/huol-ufrn/acesso-a-informacao/dados-abertos-1/SEGOV/01-comissoes-institucionais-permanentes-referencia_-ano-de-2023.pdf/@@download/file',
#   'id': 'c8596b1a-5b6a-4750-b8f8-6f5f8c082fde'},
#  {'tamanho': 0,
#   'dataCatalogacao': '30/01/2025',
#   'dataUltimaAtualizacaoArquivo': '22/01/2025',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Relação de comissões institucionais permanentes referente a 01/01/2024 a 31/12/2024',
#   'titulo': '01. Comissões Institucionais Permanentes',
#   'formato': 'PDF',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '6162d5bd-e6d8-4a2e-b4d7-339356c2b167',
#   'link': 'https://www.gov.br/ebserh/pt-br/hospitais-universitarios/regiao-nordeste/huol-ufrn/acesso-a-informacao/dados-abertos-1/SEGOV/01-comissoes-institucionais-permanentes-referencia_-ano-de-2024.pdf/view',
#   'id': '918c51c3-f992-4f93-87d5-955077001bfc'},
#  {'tamanho': 0,
#   'dataCatalogacao': '30/01/2025',
#   'dataUltimaAtualizacaoArquivo': '22/01/2025',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Relação de comissões institucionais permanentes referente a 01/01/2024 a 31/12/2024 referente a 01/01/2024 a 31/12/2024',
#   'titulo': '01.\tComissões Institucionais Permanentes',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '6162d5bd-e6d8-4a2e-b4d7-339356c2b167',
#   'link': 'https://www.gov.br/ebserh/pt-br/hospitais-universitarios/regiao-nordeste/huol-ufrn/acesso-a-informacao/dados-abertos-1/SEGOV/01-comissoes-institucionais-permanentes-referencia_-ano-de-2024.csv/view',
#   'id': '8c54ac45-13a7-463e-9f66-b8ae3c0547e5'},
#  {'tamanho': 0,
#   'dataCatalogacao': '29/01/2024',
#   'dataUltimaAtualizacaoArquivo': '29/01/2024',
#   'quantidadeDownloads': None,
# ...
#   'titulo': 'Metadados - Levantamentos Sísmicos Públicos 2023',
#   'formato': 'PDF',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '25cb5062-6c5c-46e5-961b-9afa66966c11',
#   'link': 'https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/arquivos-acervo-de-dados-tecnicos/metadados-sismicos-publicos-1.pdf',
#   'id': 'b9adf875-d488-47f3-96a1-0dd5709ab2e9'},
#  {'tamanho': 0,
#   'dataCatalogacao': '23/02/2023',
#   'dataUltimaAtualizacaoArquivo': 'Indisponível (Resposta diferente do código 200)',
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Levantamentos Sísmicos Públicos 2023',
#   'titulo': 'Levantamentos Sísmicos Públicos 2023',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '25cb5062-6c5c-46e5-961b-9afa66966c11',
#   'link': 'https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/arquivos-acervo-de-dados-tecnicos/sismicos-publicos-2023.csv',
#   'id': 'df93aeb0-fde8-421d-a39d-de349e52f08e'},
#  {'tamanho': 0,
#   'dataCatalogacao': '04/04/2023',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos da UFU - 2021',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-2021#{}',
#   'id': 'c41aa852-28cc-4194-a816-7daad1f65739'},
#  {'tamanho': 0,
#   'dataCatalogacao': '04/04/2023',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos da UFU - 2022',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-2022#{}',
#   'id': '465af466-25d4-4b20-a905-48710de7a6a2'},
#  {'tamanho': 0,
#   'dataCatalogacao': '02/06/2023',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos da UFU - Janeiro/23',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-da-ufu-janeiro23#{}',
#   'id': '35c02cb5-c630-4c41-88fd-bf72be32b225'},
#  {'tamanho': 0,
#   'dataCatalogacao': '02/06/2023',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos da UFU - Fevereiro/23',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-da-ufu-fevereiro23#{}',
#   'id': '54a744c1-abc1-4377-a072-de1332b4e919'},
#  {'tamanho': 0,
#   'dataCatalogacao': '02/06/2023',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos da UFU - Março/23',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-da-ufu-marco23#{}',
#   'id': '0745aae9-2906-485d-94bf-5033a79bbd3d'},
#  {'tamanho': 0,
#   'dataCatalogacao': '02/06/2023',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos da UFU - Abril/23',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-da-ufu-abril23#{}',
#   'id': '580bcfd4-e1f8-4adf-8ff5-7b254e4ea693'},
#  {'tamanho': 0,
#   'dataCatalogacao': '14/07/2023',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos da UFU - Maio/2023',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-da-ufu-maio23#{}',
#   'id': '83692cc9-34a7-47f0-b9a4-bcf6c01aedf3'},
#  {'tamanho': 0,
#   'dataCatalogacao': '14/07/2023',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos da UFU - Junho/2023',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-da-ufu-junho23#{}',
#   'id': '0501af23-a953-4e70-af6e-4f3621d3b2e6'},
#  {'tamanho': 0,
#   'dataCatalogacao': '12/09/2023',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos da UFU - Julho/23 ',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-da-ufu-julho23#{}',
#   'id': '050684e7-e933-4cff-94c0-d14f35aad7bd'},
#  {'tamanho': 0,
#   'dataCatalogacao': '25/10/2023',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos da UFU - Agosto/2023',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-da-ufu-agosto2023#{}',
#   'id': '47f557f6-821d-4cb5-a6d7-df66e8ab9a08'},
#  {'tamanho': 0,
#   'dataCatalogacao': '25/10/2023',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos da UFU - Setembro/2023',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-da-ufu-setembro2023#{}',
#   'id': '49a413a5-de34-427c-b0ac-cc528c2cc33d'},
#  {'tamanho': 0,
#   'dataCatalogacao': '17/01/2024',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos da UFU - Outubro/2023',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-da-ufu-outubro2023#{}',
#   'id': 'bd551b5d-b3c0-4fdd-8020-dd29de9f6e5a'},
#  {'tamanho': 0,
#   'dataCatalogacao': '17/01/2024',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos da UFU - Novembro/2023',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-da-ufu-novembro2023#{}',
#   'id': '0ea3eac2-47f4-42ca-bf87-ac989b54d579'},
#  {'tamanho': 0,
#   'dataCatalogacao': '17/01/2024',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos da UFU - Dezembro/2023',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-da-ufu-dezembro2023#{}',
#   'id': '1edaf0d5-477f-44bf-bdd7-4b988e21e436'},
#  {'tamanho': 0,
#   'dataCatalogacao': '05/04/2024',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos Biblioteca UFU - Janeiro/2024 ',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-biblioteca-ufu-janeiro2024#{}',
#   'id': '39ae09e0-c581-40dd-bb33-b46440bdc3ab'},
#  {'tamanho': 0,
#   'dataCatalogacao': '05/04/2024',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos Biblioteca UFU - Fevereiro/2024 ',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-biblioteca-ufu-fevereiro2024#{}',
#   'id': 'd5f5e2ed-7f9f-45af-bc54-b790a8afa35e'},
#  {'tamanho': 0,
#   'dataCatalogacao': '06/08/2024',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos Biblioteca UFU - Março/2024',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-biblioteca-ufu-marco2024#{}',
#   'id': '33c67be8-357c-446c-9c46-0d4a98cca282'},
#  {'tamanho': 0,
#   'dataCatalogacao': '06/08/2024',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos Biblioteca UFU - Abril/2024',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-biblioteca-ufu-abril2024#{}',
#   'id': 'da585062-e9dc-40b5-a462-35750b159944'},
#  {'tamanho': 0,
#   'dataCatalogacao': '06/08/2024',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos Biblioteca UFU - Maio/2024',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-biblioteca-ufu-maio2024#{}',
#   'id': '33b558e1-5827-4dde-9e2e-2822c529111a'},
#  {'tamanho': 0,
#   'dataCatalogacao': '06/08/2024',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos Biblioteca UFU - Junho/2024',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-biblioteca-ufu-junho2024#{}',
#   'id': 'c36af6ef-f429-4eaf-8af6-3aeda0ec48c9'},
#  {'tamanho': 0,
#   'dataCatalogacao': '23/10/2024',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos Biblioteca UFU - Julho/2024',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-biblioteca-ufu-julho2024#{}',
#   'id': '3b160b75-d269-4a78-a0ef-115fa35f76c2'},
#  {'tamanho': 0,
#   'dataCatalogacao': '23/10/2024',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos Biblioteca UFU – Agosto/2024 ',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-biblioteca-ufu-agosto2024#{}',
#   'id': '4625f172-b9a3-43ad-8c29-19c423192deb'},
#  {'tamanho': 0,
#   'dataCatalogacao': '23/10/2024',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos Biblioteca UFU – Setembro/2024 ',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-biblioteca-ufu-setembro2024#{}',
#   'id': '6dede055-dbd0-4608-8e59-c24464755791'},
#  {'tamanho': 0,
#   'dataCatalogacao': '19/12/2024',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos Biblioteca UFU – Outubro/2024',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-biblioteca-ufu-outubro2024#{}',
#   'id': '3450e25b-15c9-4122-b6f1-d07618bdbaab'},
#  {'tamanho': 0,
#   'dataCatalogacao': '19/12/2024',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos Biblioteca UFU – Novembro/2024',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-biblioteca-ufu-novembro2024#{}',
#   'id': '6311bc7b-bc6a-45bf-b0b9-4155afd0de15'},
#  {'tamanho': 0,
#   'dataCatalogacao': '17/02/2025',
#   'dataUltimaAtualizacaoArquivo': "Indisponível (Cabeçalho 'Last-modified' não encontrado ou inválido)",
#   'quantidadeDownloads': None,
#   'nomeArquivo': None,
#   'descricao': 'Periódicos, fascículos, artigos.',
#   'titulo': 'Acervo de Periódicos Biblioteca UFU – Dezembro/2024',
#   'formato': 'CSV',
#   'tipo': 'DADOS',
#   'numOrdem': None,
#   'idConjuntoDados': '165f967f-70ec-4e4c-ba7c-26fe98912643',
#   'link': 'https://dados.ufu.br/recurso/acervo-de-periodicos-biblioteca-ufu-dezembro2024#{}',
#   'id': '0060255a-f93c-4f05-868a-caaca255756a'},
#  ...]

# %%
print(len(sem_recurso))
for i in range(len(sem_recurso)):
    try:
        print(sem_recurso[1]['recursos'])
    except:
        pass
# Out:
# 361

# %% [markdown]
# ## Schemas

# %% [markdown]
# ### Schema catalogo

# %%
[
  {
    "id": "string",
    "title": "string",
    "nome": "string",
    "catalogacao": "string",
    "nomeOrganizacao": "string",
    "ultimaAlteracaoMetadados": "string",
    "ultimaAtualizacaoDados": "string",
    "isAtualizado": True
  }
]
# Out:
# [{'id': 'string',
#   'title': 'string',
#   'nome': 'string',
#   'catalogacao': 'string',
#   'nomeOrganizacao': 'string',
#   'ultimaAlteracaoMetadados': 'string',
#   'ultimaAtualizacaoDados': 'string',
#   'isAtualizado': True}]

# %% [markdown]
# ### schema Detalhamento de conjunto

# %%
{
  "id": "string",
  "titulo": "string",
  "nome": "string",
  "organizacao": "string",
  "descricao": "string",
  "licenca": "string",
  "responsavel": "string",
  "emailResponsavel": "string",
  "periodicidade": "INVALIDO",
  "temas": [
    {
      "name": "string",
      "title": "string"
    }
  ],
  "tags": [
    {
      "id": "string",
      "name": "string",
      "display_name": "string"
    }
  ],
  "coberturaTemporalInicio": "2025-10-06",
  "coberturaTemporalFim": "2025-10-06",
  "coberturaEspacial": "INVALIDO",
  "valorCoberturaEspacial": "string",
  "granularidadeEspacial": "INVALIDO",
  "versao": "string",
  "atualizacaoVersao": true,
  "visibilidade": "INVALIDO",
  "descontinuado": true,
  "dataDescontinuacao": "2025-10-06",
  "reuso": true,
  "recursos": [
    {
      "dataUltimaAtualizacaoArquivo": "string",
      "dataCatalogacao": "string",
      "quantidadeDownloads": 0,
      "nomeArquivo": "string",
      "link": "string",
      "idConjuntoDados": "string",
      "titulo": "string",
      "formato": "string",
      "tipo": "INVALIDO",
      "numOrdem": 0,
      "descricao": "string",
      "tamanho": 0,
      "id": "string"
    }
  ],
  "conjuntoDadosAssociados": [],
  "dataUltimaAtualizacaoMetadados": "string",
  "dataUltimaAtualizacaoArquivo": "string",
  "dataCatalogacao": "string",
  "atualizado": "string",
  "dadosRacaEtnia": true,
  "dadosGenero": true,
  "ods": [
    0
  ],
  "observanciaLegal": "string",
  "dadosAbertos": "string",
  "selo": "string",
  "origemCadastro": "string"
}

# %% [markdown]
# ## Criação da VectorStore

# %% [markdown]
# ### VectorStore

# %% [markdown]
# Será utilizado Qdrant

# %%
from qdrant_client import models, QdrantClient
from sentence_transformers import SentenceTransformer

# %% [markdown]
# Modelo de embedding para criação da VectorStore

# %%
encoder = SentenceTransformer("Qwen/Qwen3-Embedding-0.6B", device='cuda')

# %% [markdown]
# #### Cria vectorstore

# %% [markdown]
# Limpa memoria da GPU

# %%
import torch
torch.cuda.empty_cache()

# %% [markdown]
# Cria objeto client na memoria

# %%
'''Vale testar duas abordagens sugeridas na documentação do Qdrant:
1. Criar a coleção com quantização escalar (Scalar Quantization) para reduzir o tamanho do armazenamento.
2. Criar a coleção on-disk, para diminuir o uso da memoria RAM.

quantization_config=models.ScalarQuantization(
    scalar=models.ScalarQuantizationConfig(
        type=models.ScalarType.INT8,
        quantile=0.99,
        always_ram=True,
    )

'''

# como gerenciar multiplos usuários
#https://medium.com/@animesh.py/mastering-qdrant-a-friendly-guide-to-your-first-vector-database-ecb826d49c8c

#clientd = QdrantClient(":memory:")
clientd = QdrantClient(path="../metadados/VectorStore") # Carrega vectorstore em disco

catalogo_name = "Catalogo_metadados"
recurso_name = "Recurso_metadados"

clientd.create_collection(
    collection_name=recurso_name, # nome da coleção
    vectors_config=models.VectorParams(
        size=encoder.get_sentence_embedding_dimension(),  # Vector size is defined by used model
        distance=models.Distance.COSINE, # Metrica de similaridade
    ),
)
# Out:
# True

# %% [markdown]
# Cria uma vectorStore em batches

# %%
import torch
import gc

def limpar_memoria():
    gc.collect()                 # Coleta lixo do Python (variáveis sem referência)
    torch.cuda.empty_cache()     # Esvazia o cache de memória alocada pelo PyTorch
    torch.cuda.ipc_collect()

# %%
limpar_memoria()

# %%
@torch.no_grad()
def lotes(documents, inicio:int, batch_size:int)->None:

    ids = []
    payloads = []
    sentences = []
    vectors = []

    docs = documents[inicio : inicio+batch_size]

    for doc in docs:
        ids.append(doc.get('id'))
        payloads.append(doc)
        sentences.append(doc.get('descricao'))
    
    try:    
        vectors = encoder.encode(sentences)
        
        clientd.upsert(
        collection_name="Recurso_metadados",
        points=models.Batch(
            ids=ids,
            payloads=payloads,
            vectors=vectors),
        
        )
    except (RuntimeError, MemoryError, Exception) as e:
        print(f'Erro no lote {inicio} : {inicio+batch_size}')
        print(e)

    del vectors, payloads, ids, sentences, docs
    limpar_memoria()

# %%
limpar_memoria()
batch_size = 8
for i in range(0, len(rec_documents), batch_size):
    print(i)
    lotes(rec_documents, i, batch_size)
    limpar_memoria()
# Out:
# 0
# 8
# 16
# 24
# 32
# 40
# 48
# 56
# 64
# 72
# 80
# 88
# 96
# 104
# 112
# 120
# 128
# 136
# 144
# 152
# 160
# 168
# 176
# 184
# 192
# 200
# 208
# 216
# 224
# 232
# 240
# 248
# 256
# 264
# 272
# 280
# 288
# 296
# 304
# 312
# 320
# 328
# 336
# 344
# 352
# 360
# 368
# 376
# 384
# 392
# 400
# 408
# 416
# 424
# 432
# 440
# 448
# 456
# 464
# 472
# 480
# 488
# 496
# 504
# 512
# 520
# 528
# 536
# 544
# 552
# 560
# 568
# 576
# 584
# 592
# 600
# 608
# 616
# 624
# 632
# Erro no lote 632 : 640
# Point id ati-xlsx-atividades-de-extensao is not a valid UUID
# 640
# 648
# 656
# 664
# 672
# 680
# 688
# 696
# 704
# 712
# 720
# 728
# 736
# 744
# 752
# 760
# 768
# 776
# 784
# 792
# 800
# 808
# 816
# 824
# 832
# 840
# 848
# 856
# 864
# 872
# 880
# 888
# 896
# 904
# 912
# 920
# 928
# 936
# 944
# 952
# 960
# 968
# 976
# 984
# 992
# 1000
# 1008
# 1016
# 1024
# 1032
# 1040
# 1048
# 1056
# 1064
# 1072
# 1080
# 1088
# 1096
# 1104
# 1112
# 1120
# 1128
# 1136
# 1144
# 1152
# 1160
# 1168
# 1176
# 1184
# 1192
# 1200
# 1208
# 1216
# 1224
# 1232
# 1240
# 1248
# 1256
# 1264
# 1272
# 1280
# 1288
# 1296
# 1304
# 1312
# 1320
# 1328
# 1336
# 1344
# 1352
# 1360
# 1368
# 1376
# 1384
# 1392
# 1400
# 1408
# 1416
# 1424
# 1432
# 1440
# 1448
# 1456
# 1464
# 1472
# 1480
# 1488
# 1496
# 1504
# 1512
# 1520
# 1528
# 1536
# 1544
# 1552
# 1560
# 1568
# 1576
# 1584
# 1592
# 1600
# 1608
# 1616
# 1624
# 1632
# 1640
# Erro no lote 1640 : 1648
# 'NoneType' object is not subscriptable
# 1648
# 1656
# 1664
# Erro no lote 1664 : 1672
# 'NoneType' object is not subscriptable
# 1672
# 1680
# Erro no lote 1680 : 1688
# 'NoneType' object is not subscriptable
# 1688
# Erro no lote 1688 : 1696
# 19504
# 19512
# 19520
# 19528
# 19536
# 19544
# 19552
# 19560
# 19568
# 19576
# 19584
# 19592
# 19600
# 19608
# 19616
# 19624
# 19632
# 19640
# 19648
# 19656
# 19664
# 19672
# 19680
# 19688
# 19696
# 19704
# 19712
# 19720
# 19728
# 19736
# 19744
# 19752
# 19760
# 19768
# 19776
# 19784
# 19792
# 19800
# 19808
# 19816
# 19824
# 19832
# 19840
# 19848
# 19856
# 19864
# 19872
# 19880
# 19888
# 19896
# 19904
# 19912
# 19920
# 19928
# 19936
# 19944
# 19952
# 19960
# 19968
# 19976
# 19984
# 19992
# 20000
# 20008
# 20016
# 20024
# 20032
# 20040
# 20048
# 20056
# 20064
# 20072
# 20080
# 20088
# 20096
# 20104
# 20112
# 20120
# 20128
# 20136
# 20144
# 20152
# 20160
# 20168
# 20176
# 20184
# 20192
# 20200
# 20208
# 20216
# 20224
# 20232
# 20240
# /tmp/ipykernel_240341/782947681.py:19: UserWarning: Local mode is not recommended for collections with more than 20,000 points. Current collection contains 20003 points. Consider using Qdrant in Docker or Qdrant Cloud for better performance with large datasets.
#   clientd.upsert(
# 20248
# 20256
# 20264
# 20272
# 20280
# 20288
# 20296
# 20304
# 20312
# 20320
# 20328
# 20336
# 20344
# 20352
# 20360
# Erro no lote 20360 : 20368
# Point id dip-csv-diplomas-da-ufs is not a valid UUID
# 20368
# Erro no lote 20368 : 20376
# Point id dis-csv-discentes-de-graduacao-de-2018 is not a valid UUID
# 20376
# Erro no lote 20376 : 20384
# Point id dis-csv-discentes-de-graduacao-de-2014 is not a valid UUID
# 20384
# Erro no lote 20384 : 20392
# Point id dis-csv-discentes-de-graduacao-de-2013 is not a valid UUID
# 20392
# Erro no lote 20392 : 20400
# Point id dis-csv-discentes-de-pos-graduacao-de-2023 is not a valid UUID
# 20400
# Erro no lote 20400 : 20408
# Point id dis-csv-discentes-de-pos-graduacao-de-2015 is not a valid UUID
# 20408
# Erro no lote 20408 : 20416
# Point id dis-csv-discentes-de-residencia-de-2024 is not a valid UUID
# 20416
# Erro no lote 20416 : 20424
# Point id dis-csv-discentes-do-codap-de-2019 is not a valid UUID
# 20424
# Erro no lote 20424 : 20432
# Point id dis-csv-discentes-do-codap-de-2017 is not a valid UUID
# 20432
# 20440
# 20448
# 20456
# 20464
# 20472
# 20480
# 20488
# 20496
# 20504
# 20512
# 20520
# 20528
# 20536
# 20544
# 20552
# 20560
# 20568
# 20576
# 20584
# 20592
# 20600
# 20608
# 20616
# 20624
# Erro no lote 20624 : 20632
# Point id doc-xlsx-docentes-da-ufs is not a valid UUID
# 20632
# 20640
# Erro no lote 20640 : 20648
# Point id doc-csv-docentes-externos-da-ufs is not a valid UUID
# 20648
# Erro no lote 20648 : 20656
# CUDA out of memory. Tried to allocate 146.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 69.12 MiB is free. Including non-PyTorch memory, this process has 5.55 GiB memory in use. Of the allocated memory 5.07 GiB is allocated by PyTorch, and 385.54 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 79.12 MiB is free. Including non-PyTorch memory, this process has 5.54 GiB memory in use. Of the allocated memory 4.98 GiB is allocated by PyTorch, and 471.37 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 33128
# Erro no lote 33128 : 33136
# CUDA out of memory. Tried to allocate 152.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 81.12 MiB is free. Including non-PyTorch memory, this process has 5.54 GiB memory in use. Of the allocated memory 5.05 GiB is allocated by PyTorch, and 393.77 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 33136
# Erro no lote 33136 : 33144
# CUDA out of memory. Tried to allocate 190.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 79.12 MiB is free. Including non-PyTorch memory, this process has 5.54 GiB memory in use. Of the allocated memory 4.97 GiB is allocated by PyTorch, and 471.68 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 33144
# Erro no lote 33144 : 33152
# CUDA out of memory. Tried to allocate 138.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 163.12 MiB is free. Including non-PyTorch memory, this process has 5.46 GiB memory in use. Of the allocated memory 5.04 GiB is allocated by PyTorch, and 320.29 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 33152
# Erro no lote 33152 : 33160
# CUDA out of memory. Tried to allocate 138.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 163.12 MiB is free. Including non-PyTorch memory, this process has 5.46 GiB memory in use. Of the allocated memory 5.05 GiB is allocated by PyTorch, and 314.65 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 33160
# Erro no lote 33160 : 33168
# CUDA out of memory. Tried to allocate 116.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 133.12 MiB is free. Including non-PyTorch memory, this process has 5.48 GiB memory in use. Of the allocated memory 4.67 GiB is allocated by PyTorch, and 725.54 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 33168
# Erro no lote 33168 : 33176
# CUDA out of memory. Tried to allocate 132.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 111.12 MiB is free. Including non-PyTorch memory, this process has 5.51 GiB memory in use. Of the allocated memory 5.12 GiB is allocated by PyTorch, and 293.87 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 33176
# Erro no lote 33176 : 33184
# CUDA out of memory. Tried to allocate 132.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 111.12 MiB is free. Including non-PyTorch memory, this process has 5.51 GiB memory in use. Of the allocated memory 5.12 GiB is allocated by PyTorch, and 293.87 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 33184
# Erro no lote 33184 : 33192
# CUDA out of memory. Tried to allocate 98.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 71.12 MiB is free. Including non-PyTorch memory, this process has 5.54 GiB memory in use. Of the allocated memory 5.14 GiB is allocated by PyTorch, and 313.08 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 33192
# 33200
# 33208
# 33216
# 33224
# 33232
# 33240
# 33248
# 33256
# 33264
# 33272
# 33280
# 33288
# 33296
# 33304
# 33312
# 33320
# 33328
# 33336
# 33344
# 33352
# 33360
# 33368
# 33376
# 33384
# 33392
# 33400
# 33408
# 33416
# 33424
# 33432
# 33440
# 33448
# 33456
# 33464
# 33472
# 33480
# 33488
# 33496
# 33504
# 33512
# 33520
# 33528
# 33536
# 33544
# 33552
# 33560
# 33568
# 33576
# 33584
# 33592
# 33600
# 33608
# 33616
# 33624
# 33632
# 33640
# 33648
# 33656
# 33664
# 33672
# 33680
# 33688
# 33696
# 33704
# 33712
# 33720
# 33728
# 33736
# 33744
# 33752
# 33760
# 33768
# 33776
# 33784
# 33792
# 33800
# 33808
# 33816
# 33824
# 33832
# 33840
# 33848
# 33856
# 33864
# 33872
# 33880
# 33888
# 33896
# 33904
# 33912
# 33920
# 33928
# 33936
# 33944
# 33952
# 33960
# 33968
# 33976
# 33984
# 33992
# 34000
# 34008
# 34016
# 34024
# 34032
# 34040
# 34048
# 34056
# 34064
# 34072
# 34080
# Erro no lote 34080 : 34088
# Point id gru-xlsx-grupos-de-pesquisa is not a valid UUID
# 34088
# 34096
# 34104
# 34112
# 34120
# 34128
# 34136
# 34144
# 34152
# 34160
# 34168
# 34176
# 34184
# 34192
# 34200
# 34208
# 34216
# 34224
# 34232
# 34240
# 34248
# 34256
# 34264
# 34272
# 34280
# 34288
# 34296
# 34304
# 34312
# 34320
# 34328
# 34336
# 34344
# 34352
# 34360
# 34368
# 34376
# 34384
# 34392
# 34400
# 34408
# 34416
# 34424
# 34432
# 34440
# 34448
# 34456
# 34464
# 34472
# 34480
# 34488
# 34496
# 34504
# 34512
# 34520
# 34528
# 34536
# 34544
# 34552
# 34560
# 34568
# 34576
# 34584
# 34592
# 34600
# 34608
# 34616
# 34624
# 34632
# 34640
# 34648
# 34656
# 34664
# 34672
# 34680
# 34688
# 34696
# 34704
# 34712
# 34720
# 34728
# 34736
# 34744
# 34752
# 34760
# 34768
# 34776
# 34784
# 34792
# 34800
# 34808
# 34816
# 34824
# 34832
# 34840
# 34848
# 34856
# 34864
# 34872
# 34880
# 34888
# 34896
# 34904
# 34912
# 34920
# 34928
# 34936
# 34944
# 34952
# 34960
# 34968
# 34976
# 34984
# 34992
# 35000
# 35008
# 35016
# 35024
# 35032
# 35040
# 35048
# 35056
# 35064
# 35072
# 35080
# 35088
# 35096
# 35104
# 35112
# 35120
# 35128
# 35136
# 35144
# 35152
# 35160
# 35168
# 35176
# 35184
# 35192
# 35200
# 35208
# 35216
# 35224
# 35232
# 35240
# 35248
# 35256
# 35264
# 35272
# 35280
# 35288
# 35296
# 35304
# 35312
# 35320
# 35328
# 35336
# 35344
# 35352
# 35360
# 35368
# 35376
# 35384
# 35392
# 35400
# 35408
# 35416
# 35424
# 35432
# 35440
# 35448
# 35456
# 35464
# 35472
# Erro no lote 35472 : 35480
# CUDA out of memory. Tried to allocate 98.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 139.12 MiB is free. Including non-PyTorch memory, this process has 5.48 GiB memory in use. Of the allocated memory 5.00 GiB is allocated by PyTorch, and 386.91 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 35480
# Erro no lote 35480 : 35488
# CUDA out of memory. Tried to allocate 290.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 47.12 MiB is free. Including non-PyTorch memory, this process has 5.57 GiB memory in use. Of the allocated memory 5.21 GiB is allocated by PyTorch, and 264.06 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 35488
# Erro no lote 35488 : 35496
# CUDA out of memory. Tried to allocate 80.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 65.12 MiB is free. Including non-PyTorch memory, this process has 5.55 GiB memory in use. Of the allocated memory 5.13 GiB is allocated by PyTorch, and 327.40 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 35496
# Erro no lote 35496 : 35504
# CUDA out of memory. Tried to allocate 80.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 65.12 MiB is free. Including non-PyTorch memory, this process has 5.55 GiB memory in use. Of the allocated memory 5.13 GiB is allocated by PyTorch, and 327.40 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 35504
# Erro no lote 35504 : 35512
# CUDA out of memory. Tried to allocate 290.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 51.12 MiB is free. Including non-PyTorch memory, this process has 5.56 GiB memory in use. Of the allocated memory 5.20 GiB is allocated by PyTorch, and 268.01 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 35512
# Erro no lote 35512 : 35520
# CUDA out of memory. Tried to allocate 290.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 51.12 MiB is free. Including non-PyTorch memory, this process has 5.56 GiB memory in use. Of the allocated memory 5.20 GiB is allocated by PyTorch, and 268.01 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 35520
# Erro no lote 35520 : 35528
# CUDA out of memory. Tried to allocate 290.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 51.12 MiB is free. Including non-PyTorch memory, this process has 5.56 GiB memory in use. Of the allocated memory 5.20 GiB is allocated by PyTorch, and 268.01 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 35528
# Erro no lote 35528 : 35536
# CUDA out of memory. Tried to allocate 290.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 51.12 MiB is free. Including non-PyTorch memory, this process has 5.56 GiB memory in use. Of the allocated memory 5.20 GiB is allocated by PyTorch, and 268.01 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 35536
# Erro no lote 35536 : 35544
# CUDA out of memory. Tried to allocate 290.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 51.12 MiB is free. Including non-PyTorch memory, this process has 5.56 GiB memory in use. Of the allocated memory 5.20 GiB is allocated by PyTorch, and 268.01 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 35544
# Erro no lote 35544 : 35552
# CUDA out of memory. Tried to allocate 98.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 139.12 MiB is free. Including non-PyTorch memory, this process has 5.48 GiB memory in use. Of the allocated memory 4.99 GiB is allocated by PyTorch, and 391.53 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 35552
# 35560
# 35568
# 35576
# 35584
# 35592
# 35600
# 35608
# 35616
# 35624
# 35632
# 35640
# 35648
# 35656
# 35664
# 35672
# 35680
# 35688
# 35696
# 35704
# 35712
# 35720
# 35728
# 35736
# 35744
# 35752
# 35760
# 35768
# 35776
# 35784
# 35792
# 35800
# 35808
# 35816
# 35824
# 35832
# 35840
# 35848
# 35856
# 35864
# 35872
# 35880
# 35888
# 35896
# 35904
# 35912
# 35920
# 35928
# 35936
# 35944
# 35952
# 35960
# 35968
# 35976
# 35984
# 35992
# 36000
# 36008
# 36016
# 36024
# 36032
# 36040
# 36048
# 36056
# 36064
# 36072
# 36080
# 36088
# 36096
# 36104
# 36112
# 36120
# 36128
# 36136
# 36144
# 36152
# 36160
# 36168
# 36176
# 36184
# 36192
# 36200
# 36208
# 36216
# 36224
# 36232
# 36240
# 36248
# 36256
# Erro no lote 36256 : 36264
# 'NoneType' object is not subscriptable
# 36264
# Erro no lote 36264 : 36272
# 'NoneType' object is not subscriptable
# 36272
# 36280
# 36288
# 36296
# 36304
# 36312
# 36320
# 36328
# 36336
# Erro no lote 36336 : 36344
# 'NoneType' object is not subscriptable
# 36344
# Erro no lote 36344 : 36352
# 'NoneType' object is not subscriptable
# 36352
# 36360
# 36368
# 36376
# 36384
# 36392
# 36400
# Erro no lote 36400 : 36408
# 'NoneType' object is not subscriptable
# 36408
# 36416
# 36424
# 36432
# 36440
# 36448
# 36456
# 36464
# 36472
# 36480
# 36488
# 36496
# 36504
# 36512
# 36520
# 36528
# 36536
# 36544
# 36552
# 36560
# 36568
# 36576
# 36584
# 36592
# 36600
# 36608
# 36616
# 36624
# 36632
# 36640
# Erro no lote 36640 : 36648
# 'NoneType' object is not subscriptable
# 36648
# 36656
# Erro no lote 36656 : 36664
# 'NoneType' object is not subscriptable
# 36664
# 36672
# 36680
# Erro no lote 36680 : 36688
# 'NoneType' object is not subscriptable
# 36688
# 36696
# 36704
# 36712
# 36720
00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 61.12 MiB is free. Including non-PyTorch memory, this process has 5.55 GiB memory in use. Of the allocated memory 4.70 GiB is allocated by PyTorch, and 770.26 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 47816
# 47824
# 47832
# 47840
# Erro no lote 47840 : 47848
# CUDA out of memory. Tried to allocate 288.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 303.12 MiB is free. Including non-PyTorch memory, this process has 5.32 GiB memory in use. Of the allocated memory 4.73 GiB is allocated by PyTorch, and 495.78 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 47848
# 47856
# 47864
# 47872
# Erro no lote 47872 : 47880
# CUDA out of memory. Tried to allocate 276.00 MiB. GPU 0 has a total capacity of 5.64 GiB of which 109.12 MiB is free. Including non-PyTorch memory, this process has 5.51 GiB memory in use. Of the allocated memory 4.67 GiB is allocated by PyTorch, and 752.28 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# 47880
# 47888
# 47896
# 47904
# 47912
# 47920
# 47928
# 47936
# 47944
# 47952
# 47960
# 47968
# 47976
# 47984
# 47992
# 48000
# 48008
# 48016
# 48024
# 48032
# 48040
# 48048
# 48056
# 48064
# 48072
# 48080
# 48088
# 48096
# 48104
# 48112
# 48120
# 48128
# 48136
# 48144
# 48152
# 48160
# 48168
# 48176
# 48184
# 48192
# 48200
# 48208
# 48216
# 48224
# 48232
# 48240
# 48248
# 48256
# 48264
# 48272
# 48280
# 48288
# 48296
# 48304
# 48312
# 48320
# 48328
# 48336
# 48344
# 48352
# 48360
# 48368
# 48376
# 48384
# 48392
# 48400
# 48408
# 48416
# 48424
# 48432
# 48440
# 48448
# 48456
# 48464
# 48472
# 48480
# 48488
# 48496
# 48504
# 48512
# 48520
# 48528
# 48536
# 48544
# 48552
# 48560
# 48568
# 48576
# 48584
# 48592
# 48600
# 48608
# 48616
# 48624
# 48632
# 48640
# 48648
# 48656
# 48664
# 48672
# 48680
# 48688
# 48696
# 48704
# 48712
# 48720
# 48728
# 48736
# 48744
# 48752
# 48760
# 48768
# 48776
# 48784
# 48792
# 48800
# 48808
# 48816
# 48824
# 48832
# 48840
# 48848
# 48856
# 48864
# 48872
# 48880
# 48888
# 48896
# 48904
# 48912
# 48920
# 48928
# 48936
# 48944
# 48952
# 48960
# 48968
# 48976
# 48984
# 48992
# 49000
# 49008
# 49016
# 49024
# 49032
# 49040
# 49048
# 49056
# 49064
# 49072
# 49080
# 49088
# 49096
# 49104
# 49112
# 49120
# 49128
# 49136
# 49144
# 49152
# 49160
# 49168
# 49176
# 49184
# 49192
# 49200
# 49208
# 49216
# 49224
# 49232
# 49240
# 49248
# 49256
# 49264
# 49272
# 49280
# 49288
# 49296
# 49304
# 49312
# 49320
# 49328
# 49336
# 49344
# 49352
# 49360
# 49368
# 49376
# 49384
# 49392
# 49400
# 49408
# 49416
# 49424
# 49432
# 49440
# 49448
# 49456
# 49464
# 49472
# 49480
# 49488
# 49496
# 49504
# 49512
# 49520
# 49528
# 49536
# 49544
# 49552
# 49560
# 49568
# 49576
# 49584
# 49592
# 49600
# 49608
# 49616
# 49624
# 49632
# 49640
# 49648
# 49656
# 49664
# 49672
# 49680
# 49688
# 63520
# 63528
# 63536
# 63544
# 63552
# 63560
# 63568
# 63576
# 63584
# 63592
# 63600
# 63608
# 63616
# 63624
# 63632
# 63640
# 63648
# 63656
# 63664
# 63672
# 63680
# 63688
# 63696
# 63704
# 63712
# 63720
# 63728
# 63736
# 63744
# 63752
# 63760
# 63768
# 63776
# 63784
# 63792
# 63800
# 63808
# 63816
# 63824
# 63832
# 63840
# 63848
# 63856
# 63864
# 63872
# 63880
# 63888
# 63896
# 63904
# 63912
# 63920
# 63928
# 63936
# 63944
# 63952
# 63960
# 63968
# 63976
# 63984
# 63992
# 64000
# 64008
# 64016
# 64024
# 64032
# 64040
# 64048
# 64056
# 64064
# 64072
# 64080
# 64088
# 64096
# 64104
# 64112
# 64120
# 64128
# 64136
# 64144
# 64152
# 64160
# 64168
# 64176
# 64184
# 64192
# 64200

# %%
@torch.no_grad()
def lotes(documents, inicio:int, batch_size:int)->None:

    ids = []
    payloads = []
    sentences = []
    vectors = []

    docs = documents[inicio : inicio+batch_size]

    for doc in docs:
        ids.append(doc.get('id'))
        payloads.append(doc)
        sentences.append(doc.get('descricao'))
    
    try:    
        vectors = encoder.encode(sentences)
        
        clientd.upsert(
        collection_name="Catalogo_metadados",
        points=models.Batch(
            ids=ids,
            payloads=payloads,
            vectors=vectors),
        
        )
    except (RuntimeError, MemoryError, Exception) as e:
        print(f'Erro no lote {inicio} : {inicio+batch_size}')

    del vectors, payloads, ids, sentences, docs
    limpar_memoria()

# %%
limpar_memoria()
batch_size = 8
for i in range(0, len(documents), batch_size):
    print(i)
    lotes(documents, i, batch_size)
    limpar_memoria()
# Out:
# 0
# 8
# 16
# 24
# 32
# 40
# 48
# 56
# 64
# 72
# 80
# 88
# 96
# 104
# 112
# 120
# 128
# 136
# 144
# 152
# Erro no lote152 : 160
# 160
# 168
# Erro no lote168 : 176
# 176
# 184
# 192
# 200
# 208
# 216
# 224
# 232
# 240
# 248
# 256
# 264
# 272
# 280
# 288
# 296
# 304
# 312
# 320
# 328
# 336
# 344
# 352
# 360
# 368
# 376
# 384
# 392
# 400
# 408
# 416
# 424
# 432
# 440
# 448
# 456
# 464
# 472
# Erro no lote472 : 480
# 480
# 488
# 496
# 504
# 512
# 520
# 528
# 536
# 544
# 552
# 560
# 568
# 576
# 584
# 592
# 600
# 608
# 616
# 624
# 632
# 640
# 648
# 656
# 664
# 672
# 680
# 688
# 696
# 704
# 712
# 720
# 728
# 736
# 744
# 752
# 760
# 768
# 776
# 784
# 792
# 800
# 808
# 816
# 824
# 832
# 840
# 848
# 856
# 864
# 872
# 880
# 888
# 896
# 904
# 912
# 920
# 928
# 936
# 944
# 952
# 960
# 968
# 976
# 984
# 992
# 1000
# 1008
# 1016
# 1024
# 1032
# 1040
# 1048
# 1056
# 1064
# 1072
# 1080
# 1088
# Erro no lote1088 : 1096
# 1096
# 1104
# Erro no lote1104 : 1112
# 1112
# 1120
# 1128
# 1136
# 1144
# 1152
# 1160
# 1168
# Erro no lote1168 : 1176
# 1176
# Erro no lote1176 : 1184
